# %%
import numpy as np
import pandas as pd
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import itertools

# %%
res = metric_fpr(
    hw[(hw['experimentVariant'] == 0) & (hw['version'] == 'v2.8.0')],
    hw[(hw['experimentVariant'] == 1) & (hw['version'] == 'v2.8.0')],
    metric_col = metric,
    n_sim = 1000,
    n_s_perc = n_s_perc,
    n_s_min = n_s_min,
    estimator = 'prop'
)
       
print(res['fpr']['fpr_95'])
plt.hist(res['aa']['pvalue'], bins = 50)
plt.style.use('ggplot')
plt.show()
# Out:
# 1.0

# %%
hw_fltrd = hw[(hw['version']!='v2.8.0')]
res = metric_fpr(
    hw_fltrd[(hw_fltrd['experimentVariant'] == 0)],
    hw_fltrd[(hw_fltrd['experimentVariant'] == 1)],
    metric_col = metric,
    n_sim = 1000,
    n_s_perc = n_s_perc,
    n_s_min = n_s_min,
    estimator = 'prop'
)

print(res['fpr']['fpr_95'])
plt.hist(res['aa']['pvalue'], bins = 50)
plt.style.use('ggplot')
plt.show()
# Out:
# 0.047
